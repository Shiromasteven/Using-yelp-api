# %%
import json
from yelpapi import YelpAPI
import pandas as pd


with open('/Users/Steven (Dad)/.secret/yelp_api.json') as f:
    
    login = json.load(f)

    
    
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)

results = yelp_api.search_query(location='Phoenix, AZ',
                               term= 'Sushi')
type(results)
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['total']
# Out:
# 836

# %%
biz = pd.DataFrame(results['businesses'])
biz.head(2)
# Out:
#                        id                                   alias  \
# 0  _n0B8mRTWP6ZfX8npDGEqw      yutaka-japanese-restaurant-phoenix
# 1  S-oLPRdhlyL5HAknBKTUcQ  harumi-sushi-and-sake-downtown-phoenix
#
#                             name  \
# 0     Yutaka Japanese Restaurant
# 1  Harumi Sushi & Sake- Downtown
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/GFyq1d...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/RGzWKj...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/yutaka-japanese-resta...           665
# 1  https://www.yelp.com/biz/harumi-sushi-and-sake...          2116
#
#                                           categories  rating  \
# 0  [{'alias': 'ramen', 'title': 'Ramen'}, {'alias...     4.5
# 1  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
#
# ...

# %%
results = yelp_api.search_query(location='Phoenix, AZ',
                               term = 'Sushi',
                               offset = 20)
biz20 = pd.DataFrame(results['businesses'])
biz20.head(2)
# Out:
#                        id                   alias            name  \
# 0  FT-mOkewYKbIs4_f2pBFqQ      sushi-vibe-phoenix      Sushi Vibe
# 1  -ITj6Pu8Gdw8MmLf0XBEKQ  sushi-on-tatum-phoenix  Sushi On Tatum
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/-zdAiw...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/6wL5aO...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/sushi-vibe-phoenix?ad...           189
# 1  https://www.yelp.com/biz/sushi-on-tatum-phoeni...           518
#
#                                           categories  rating  \
# 0        [{'alias': 'sushi', 'title': 'Sushi Bars'}]     4.5
# 1  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
#
#                                          coordinates        transactions  \
# 0  {'latitude': 33.510325, 'longitude': -112.0725...                  []
# ...

# %%
businesses40 = pd.concat([biz, biz20],
                        ignore_index = True)

display(businesses40.head(), businesses40.tail())
# Out:
#                        id                                   alias  \
# 0  _n0B8mRTWP6ZfX8npDGEqw      yutaka-japanese-restaurant-phoenix
# 1  S-oLPRdhlyL5HAknBKTUcQ  harumi-sushi-and-sake-downtown-phoenix
# 2  evdJO0v9rvVixieNEnaeJg                      sushiholic-phoenix
# 3  XFO9us6shjSRwiuLBO9T9g        kura-revolving-sushi-bar-phoenix
# 4  itJJHcstARVqibAUtxjyUQ                      o2-sushi-phoenix-2
#
#                             name  \
# 0     Yutaka Japanese Restaurant
# 1  Harumi Sushi & Sake- Downtown
# 2                     Sushiholic
# 3       Kura Revolving Sushi Bar
# 4                       O2 Sushi
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/GFyq1d...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/RGzWKj...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/Fe1HNI...      False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/ZnJz7M...      False
# ...

# %%
businesses40.to_json(orient='records')
# Out:
# '[{"id":"_n0B8mRTWP6ZfX8npDGEqw","alias":"yutaka-japanese-restaurant-phoenix","name":"Yutaka Japanese Restaurant","image_url":"https:\\/\\/s3-media1.fl.yelpcdn.com\\/bphoto\\/GFyq1dHL8and703H-qZzsw\\/o.jpg","is_closed":false,"url":"https:\\/\\/www.yelp.com\\/biz\\/yutaka-japanese-restaurant-phoenix?adjust_creative=AcExU3N3XjFWu6Ms6veu7g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AcExU3N3XjFWu6Ms6veu7g","review_count":665,"categories":[{"alias":"ramen","title":"Ramen"},{"alias":"sushi","title":"Sushi Bars"}],"rating":4.5,"coordinates":{"latitude":33.639089,"longitude":-112.063179},"transactions":["pickup","delivery"],"price":"$$","location":{"address1":"751 E Bell Rd","address2":"Ste 9","address3":"","city":"Phoenix","zip_code":"85022","country":"US","state":"AZ","display_address":["751 E Bell Rd","Ste 9","Phoenix, AZ 85022"]},"phone":"+16028438882","display_phone":"(602) 843-8882","distance":2853.1769003814},{"id":"S-oLPRdhlyL5HAknBKTUcQ","alias":"harumi-su
# ...
